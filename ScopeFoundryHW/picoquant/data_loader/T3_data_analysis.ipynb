# %%
import numpy as np
import matplotlib.pylab as plt

# %%
from data_loaders import T3DataLoader
file_name = "230117_145305_timeharp_260_t2.h5"
data = T3DataLoader(file_name)

# %%
plt.hist(data.get_start_stop_times(0))
# Out:
# (array([19224., 10401.,  5910.,  3631.,  2255.,  1530.,  1025.,   904.,
#          9961., 41669.]),
#  array([    0. ,  5002.5, 10005. , 15007.5, 20010. , 25012.5, 30015. ,
#         35017.5, 40020. , 45022.5, 50025. ]),
#  <BarContainer object of 10 artists>)

# %%
from data_loaders import HistogramDataLoader


hist_data = HistogramDataLoader('230117_143924_timeharp_260_histogram.h5')

# %%
plt.semilogy(hist_data.time_array, hist_data.time_histograms[0], label='histogram Mode')
data.calc_time_histograms(len(hist_data.time_array))
plt.semilogy(data.time_array, data.time_histograms[0], label='T3 Mode')
plt.legend()

# %%
data.calc_event_times()
plt.eventplot(data.event_times[0][:100])
plt.title('Ticks')
plt.xlabel('Time (ps)')
plt.ylabel('Signal')
# Out:
# Text(0, 0.5, 'Signal')

# %%
'1'
# Out:
# '1'
